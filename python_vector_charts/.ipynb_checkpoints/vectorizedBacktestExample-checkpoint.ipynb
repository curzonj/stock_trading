# %% [markdown]
# - http://www.eickonomics.com/posts/2014-03-25-python-vs-R-adding-TA-indicators/
# - https://www.quantstart.com/articles/Backtesting-a-Moving-Average-Crossover-in-Python-with-pandas
# - https://trello.com/c/KBbjZE02/16-dynamic-asset-allocation-market-timing
# - https://www.quantstart.com/articles/Backtesting-a-Forecasting-Strategy-for-the-SP500-in-Python-with-pandas
#
# I have concerns about how the vectorized testing is showing results. I should reproduce the buyApple strategy with a vectorized test.

# %%
# %load_ext zipline
# %pylab inline
figsize(12, 12)
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%zipline --start 2004-1-1 --end 2014-1-1 --capital-base 1000 -o perf
#
# import matplotlib.pyplot as plt
# from zipline.api import *
#
# def initialize(context):
#     pass
#
# def handle_data(context, data):
#     to_buy = context.portfolio.cash // data[symbol('AAPL')].price
#     to_buy = to_buy - 1
#     record(to_buy=to_buy)
#     if (to_buy >= 0):
#         order(symbol('AAPL'), to_buy)
#     record(A_shares=context.portfolio.positions[symbol('AAPL')].amount)
#     record(AAPL=data[symbol('AAPL')].price)
#
# def analyze(context, perf):
#     ax1 = plt.subplot(311)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value')
#
#     ax2 = plt.subplot(312, sharex=ax1)
#     perf.AAPL.plot(ax=ax2)
#     ax2.set_ylabel('AAPL stock price')
#
#     ax3 = plt.subplot(313, sharex=ax1)
#     perf.A_shares.plot(ax=ax3)
#     ax3.set_ylabel('AAPL shares')
#
#     plt.show()
# Out:
#                         AAPL  A_shares  algo_volatility  \
# 2004-01-02 21:00:00   21.280         0              NaN
# 2004-01-05 21:00:00   22.170        45         0.011225
# 2004-01-06 21:00:00   22.090        45         0.029532
# 2004-01-07 21:00:00   22.590        45         0.193105
# 2004-01-08 21:00:00   23.360        45         0.268232
# 2004-01-09 21:00:00   23.000        45         0.292428
# 2004-01-12 21:00:00   23.730        45         0.307954
# 2004-01-13 21:00:00   24.120        45         0.287542
# 2004-01-14 21:00:00   24.200        45         0.271718
# 2004-01-15 21:00:00   22.850        45         0.416831
# 2004-01-16 21:00:00   22.720        45         0.397738
# 2004-01-20 21:00:00   22.730        45         0.379337
# 2004-01-21 21:00:00   22.610        45         0.364699
# 2004-01-22 21:00:00   22.180        45         0.361202
# 2004-01-23 21:00:00   22.560        45         0.354893
# 2004-01-26 21:00:00   23.010        45         0.350707
# ...
