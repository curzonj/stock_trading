# %% [markdown]
# This is based on the following but with several changes because my main goal is to be able to plot indicators over the S&P 500 so that I can study the series.
#
# https://ntguardian.wordpress.com/2016/09/19/introduction-stock-market-data-python-1/

# %%
import pandas as pd
# Package and modules for importing data; this code may change depending on pandas version
import pandas.io.data as web
import datetime
 
# We will look at stock prices over the past year, starting at January 1, 2016
start = datetime.datetime(2000,1,1)
end = datetime.date.today()

# Let's get Apple stock data; Apple's ticker symbol is AAPL
# First argument is the series we want, second is the source ("yahoo" for Yahoo! Finance), third is the start date, fourth is the end date
apple = web.DataReader("^GSPC", "yahoo", start, end)
 
type(apple)
# Out:
# pandas.core.frame.DataFrame

# %%
apple.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971   931800000
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1009000000
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1085500000
# 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951  1092300000
# 2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971  1225200000
#
#               Adj Close
# Date
# 2000-01-03  1455.219971
# 2000-01-04  1399.420044
# 2000-01-05  1402.109985
# 2000-01-06  1403.449951
# 2000-01-07  1441.469971

# %%
import matplotlib.pyplot as plt   # Import matplotlib
# This line is necessary for the plot to appear in a Jupyter notebook
# %matplotlib inline
# Control the default size of figures in this Jupyter notebook
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 9)   # Change the size of plots
 
apple["Adj Close"].plot(grid = True) # Plot the adjusted closing price of AAPL
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import talib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-9bc7b4202a1f> in <module>()
# ----> 1 import talib
#
# ImportError: No module named 'talib'

# %%
# %%bash
# conda install -c quantopian ta-lib
# Out:
# Fetching package metadata .........
# Solving package specifications: ..........
#
# Package plan for installation in environment /Users/jcurzon/anaconda/envs/zipline:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libpng-1.6.17              |                0         184 KB
#     numpy-1.9.3                |           py34_3         2.6 MB
#     pyparsing-2.0.3            |           py34_0          66 KB
#     bcolz-0.12.1               |       np19py34_0         405 KB  quantopian
#     bottleneck-1.0.0           |       np19py34_0         153 KB
#     numexpr-2.4.6              |       np19py34_0         113 KB  quantopian
#     scipy-0.17.1               |       np19py34_1        11.9 MB
#     ta-lib-0.4.9               |       np19py34_0         835 KB  quantopian
#     matplotlib-1.4.3           |       np19py34_3        41.1 MB
#     pandas-0.16.2              |       np19py34_0         5.5 MB
#     statsmodels-0.6.1          |       np19py34_0         4.7 MB
#     zipline-1.0.2              |       np19py34_0         1.1 MB  quantopian
#     ------------------------------------------------------------
#                                            Total:        68.6 MB
#
# The following NEW packages will be INSTALLED:
#
#     ta-lib:      0.4.9-np19py34_0   quantopian
#
# The following packages will be UPDATED:
#
#     scipy:       0.17.1-np110py34_1            --> 0.17.1-np19py34_1
#
# The following packages will be SUPERCEDED by a higher-priority channel:
#
#     bcolz:       0.12.1-np110py34_0            --> 0.12.1-np19py34_0 quantopian
#     numexpr:     2.6.0-np110py34_0             --> 2.4.6-np19py34_0  quantopian
#     zipline:     1.0.2-np110py34_0  Quantopian --> 1.0.2-np19py34_0  quantopian
#
# The following packages will be DOWNGRADED due to dependency conflicts:
#
#     bottleneck:  1.0.0-np110py34_1             --> 1.0.0-np19py34_0
#     libpng:      1.6.22-0                      --> 1.6.17-0
#     matplotlib:  1.5.1-np110py34_0             --> 1.4.3-np19py34_3
#     numpy:       1.10.4-py34_2                 --> 1.9.3-py34_3
#     pandas:      0.17.1-np110py34_0            --> 0.16.2-np19py34_0
#     pyparsing:   2.1.4-py34_0                  --> 2.0.3-py34_0
#     statsmodels: 0.6.1-np110py34_1             --> 0.6.1-np19py34_0
#
# Proceed ([y]/n)?
# Fetching packages ...
# libpng-1.6.17- 100% |###############################| Time: 0:00:00 495.37 kB/s
# numpy-1.9.3-py 100% |###############################| Time: 0:00:02   1.10 MB/s
# pyparsing-2.0. 100% |###############################| Time: 0:00:00 255.35 kB/s
# bcolz-0.12.1-n 100% |###############################| Time: 0:00:00 742.49 kB/s
# bottleneck-1.0 100% |###############################| Time: 0:00:00 466.75 kB/s
# numexpr-2.4.6- 100% |###############################| Time: 0:00:00 436.12 kB/s
# scipy-0.17.1-n 100% |###############################| Time: 0:00:06   1.81 MB/s
# ta-lib-0.4.9-n 100% |###############################| Time: 0:00:00   1.06 MB/s
# matplotlib-1.4 100% |###############################| Time: 0:00:24   1.73 MB/s
# pandas-0.16.2- 100% |###############################| Time: 0:00:04   1.22 MB/s
# statsmodels-0. 100% |###############################| Time: 0:00:02   1.70 MB/s
# zipline-1.0.2- 100% |###############################| Time: 0:00:01   1.09 MB/s
# Extracting packages ...
# [      COMPLETE      ]|##################################################| 100%
# Unlinking packages ...
# [      COMPLETE      ]|##################################################| 100%
# Linking packages ...
# [      COMPLETE      ]|##################################################| 100%

# %%
import talib

# %%
normalized = apple.apply(lambda x: x / x[0])
normalized.head()
# Out:
#                 Open      High       Low     Close    Volume  Adj Close
# Date
# 2000-01-03  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# 2000-01-04  0.990451  0.984587  0.971544  0.961655  1.082850   0.961655
# 2000-01-05  0.952472  0.956204  0.957813  0.963504  1.164950   0.963504
# 2000-01-06  0.954303  0.955277  0.967838  0.964425  1.172247   0.964425
# 2000-01-07  0.955215  0.975284  0.973838  0.990551  1.314874   0.990551

# %%
normalized["Adj Close"].plot(grid = True)

# %% [markdown]
# This post has some good examples of applying technical indicators to charts in python: http://www.eickonomics.com/posts/2014-03-25-python-vs-R-adding-TA-indicators/

# %%
data = pd.DataFrame({"GSPC": apple["Adj Close"]})

# %%
data.plot()

# %%
stock_change = data.apply(lambda x: np.log(x) - np.log(x.shift(1)))
stock_change.plot()

# %%
data["200d"] = np.round(pd.rolling_mean(data["GSPC"], window = 200, center = False), 2)
data["50d"] = np.round(pd.rolling_mean(data["GSPC"], window = 50, center = False), 2)
data.plot()

# %%
data.tail(700).plot()

# %%
data["50_200_diff"] = data["50d"] - data["200d"]
data.plot(secondary_y = ["GSPC", "20d", "50d", "200d"], grid = True).axhline(y = 1, color = "black", lw = 1)
